# %% [markdown]
# <a href="https://colab.research.google.com/github/Anilbk777/EDA_titanic_dataset/blob/main/EDA_titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ##age##

# %% [markdown]
# *   Age is normally (almost) distributed
# *   20% of the values are missing
# *   There are some outliers

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.displot(kind='hist', data =df, x ='Age')

# %%
sns.displot(kind='kde', data =df, x ='Age')

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
sns.catplot(kind='box', data =df, x ='Age')

# %%
df[df['Age'] >65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
df['Age'].isnull().sum()/len(df['Age'])
# Out:
# np.float64(0.19865319865319866)

# %% [markdown]
# **Fare**

# %% [markdown]
# conclusion

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Fare'].skew()
# Out:
# np.float64(4.787316519674893)

# %%
sns.catplot(kind='box',x =df['Fare'])

# %%
df[df['Fare'] > 250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
# df[df['Survived'].isna()]

df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.catplot(kind='count', x= df['Survived'])

# %%
plt.pie(x=df['Survived'].value_counts(),labels=df['Survived'].value_counts().index, autopct='%0.1f%%')
plt.show()

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.catplot(x= df['Pclass'], kind='count')

# %%
plt.pie(x= df['Pclass'].value_counts(),labels=df['Pclass'].value_counts().index, autopct='%0.1f%%',startangle=90)
plt.legend()

plt.show()

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%0.6f%%')
plt.legend()

# %%
df['SibSp'].value_counts().plot(kind='pie', autopct='%0.1f%%',explode=[0,0,0.1,0.1,0.1,0.3,0.4])
plt.legend()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(df['Survived'],df['Pclass'],  normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Pclass'],  normalize='columns')*100)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
pd.crosstab(df['Survived'],df['Sex'],  normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
pd.crosstab(df['Survived'],df['Embarked'],  normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
pd.crosstab(df['Sex'],df['Embarked'],  normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
pd.crosstab(df['Pclass'],df['Embarked'],  normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
df[df['Survived'] ==1]['Age'].plot(kind='kde',label ='Survived')
df[df['Survived'] ==0]['Age'].plot(kind='kde',label ='not Survived')

plt.legend()
plt.show()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name'].sample(5)
# Out:
# 82           McDermott, Miss. Brigdet Delia
# 14     Vestrom, Miss. Hulda Amanda Adolfina
# 38       Vander Planke, Miss. Augusta Maria
# 364                     O'Brien, Mr. Thomas
# 723                 Hodges, Mr. Henry Price
# Name: Name, dtype: object

# %%
deck = df['Cabin'].dropna()

# %%
df['deck'] = deck.str[0]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2 = df.dropna(subset = ['deck'])

# %%
pd.crosstab(index = df2['Survived'], columns=df2['deck'])
# Out:
# deck      A   B   C   D   E  F  G  T
# Survived
# 0         8  12  24   8   8  5  2  1
# 1         7  35  35  25  24  8  2  0

# %%
df[df['deck'].isna()].shape
# Out:
# (687, 13)

# %%
# df.fillna('M', inplace=True)

df = df.astype({'deck': 'object'})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(index = df['Survived'], columns=df['deck'], normalize='columns')
# Out:
# deck             A         B        C         D     E         F    G  \
# Survived
# 0         0.533333  0.255319  0.40678  0.242424  0.25  0.384615  0.5
# 1         0.466667  0.744681  0.59322  0.757576  0.75  0.615385  0.5
#
# deck             M    T
# Survived
# 0         0.700146  1.0
# 1         0.299854  0.0

# %%
df['deck'].value_counts()
# Out:
# deck
# M    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: count, dtype: int64

# %%
pd.crosstab(index = df['deck'], columns=df['Pclass'])
# Out:
# Pclass   1    2    3
# deck
# A       15    0    0
# B       47    0    0
# C       59    0    0
# D       29    4    0
# E       25    4    3
# F        0    8    5
# G        0    0    4
# M       40  168  479
# T        1    0    0

# %%
pd.crosstab(index = df['deck'], columns=df['Pclass'])
# Out:
# Pclass   1    2    3
# deck
# A       15    0    0
# B       47    0    0
# C       59    0    0
# D       29    4    0
# E       25    4    3
# F        0    8    5
# G        0    0    4
# M       40  168  479
# T        1    0    0

# %%
numeric_df = df.select_dtypes(include='number')
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df['deck'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: deck
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    object
# dtypes: object(1)
# memory usage: 7.1+ KB

# %%
numeric_df = df.select_dtypes(include='number')
numeric_df.corr()
# Out:
#              PassengerId  Survived    Pclass     SibSp     Parch      Fare
# PassengerId     1.000000 -0.005007 -0.035144 -0.057527 -0.001652  0.012658
# Survived       -0.005007  1.000000 -0.338481 -0.035322  0.081629  0.257307
# Pclass         -0.035144 -0.338481  1.000000  0.083081  0.018443 -0.549500
# SibSp          -0.057527 -0.035322  0.083081  1.000000  0.414838  0.159651
# Parch          -0.001652  0.081629  0.018443  0.414838  1.000000  0.216225
# Fare            0.012658  0.257307 -0.549500  0.159651  0.216225  1.000000
